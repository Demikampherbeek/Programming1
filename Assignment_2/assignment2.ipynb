# %%
import pandas as pd
import numpy as np
import json
import yaml

# %%
file = open('C:/schoolprojects-main/schoolprojects-main/programming1/glucose.json')
data = json.load(file)

df = pd.read_json(data)
df.head(40)
# Out:
#         ID              time  recordtype glucose
# 0   2845.0  2019-04-25 00:08           1     109
# 1   2850.0  2019-04-25 00:50           1
# 2   2877.0  2019-04-25 07:02           1     123
# 3   2881.0  2019-04-25 07:34           1     158
# 4   2886.0  2019-04-25 08:19           1
# 5   2899.0  2019-04-25 11:01           1     139
# 6   2909.0  2019-04-25 13:14           1     151
# 7   2916.0  2019-04-25 14:17           1     129
# 8   2922.0  2019-04-25 14:45           1     161
# 9   2925.0  2019-04-25 14:55           1     184
# 10  2927.0  2019-04-25 14:59           1     178
# 11  2929.0  2019-04-25 15:00           1     178
# 12  2932.0  2019-04-25 15:11           1     121
# 13  2935.0  2019-04-25 15:18           1     111
# 14  2937.0  2019-04-25 15:22           1     106
# 15  2940.0  2019-04-25 15:37           1      91
# 16  2942.0  2019-04-25 15:38           1      97
# 17  2944.0  2019-04-25 15:44           1     106
# ...

# %%
df["glucose"] = df["glucose"].replace(r'[\s]+', np.nan, regex = True)
df['glucose'] = df['glucose'].astype('float')
df['time'] = pd.to_datetime(df['time'])
df = df.set_index(df['time'])
df = df.sort_index()
df.head()
# Out:
#                                ID                time  recordtype  glucose
# time
# 2019-04-25 00:08:00  2.845000e+03 2019-04-25 00:08:00           1    109.0
# 2019-04-25 00:14:00  1.614305e+19 2019-04-25 00:14:00           0      NaN
# 2019-04-25 00:29:00  1.614305e+19 2019-04-25 00:29:00           0      NaN
# 2019-04-25 00:44:00  1.614305e+19 2019-04-25 00:44:00           0      NaN
# 2019-04-25 00:50:00  2.850000e+03 2019-04-25 00:50:00           1      NaN

# %%
print('quantity features', len(df.axes[1])) # quantity of the features
obs = df.groupby(["ID"]).sum().count()
print(obs) # quantity of the observations

MV = (df["glucose"].isnull().sum()) # missing values in glucose column
TV = MV + (df['glucose'].count()) # total values in glucose column

print('percentage missing data glucose:',MV/TV)

# min_data = df['time'].min()
# max_data = df['time'].max()
print('time range is:', min_data,'to', max_data)
# Out:
# quantity features 4
# recordtype    56
# glucose       56
# dtype: int64
# percentage missing data glucose: 0.6176470588235294
# time range is: 2019-04-25 00:08:00 to 2019-04-25 23:48:00
# C:\Users\dckam\AppData\Local\Temp\ipykernel_6020\1583643649.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   obs = df.groupby(["ID"]).sum().count()

# %%
df["interpolated"] = df["glucose"].interpolate(method="slinear")
df.head()
# Out:
#                                ID                time  recordtype  glucose  \
# time
# 2019-04-25 00:08:00  2.845000e+03 2019-04-25 00:08:00           1    109.0
# 2019-04-25 00:14:00  1.614305e+19 2019-04-25 00:14:00           0      NaN
# 2019-04-25 00:29:00  1.614305e+19 2019-04-25 00:29:00           0      NaN
# 2019-04-25 00:44:00  1.614305e+19 2019-04-25 00:44:00           0      NaN
# 2019-04-25 00:50:00  2.850000e+03 2019-04-25 00:50:00           1      NaN
#
#                      interpolated
# time
# 2019-04-25 00:08:00    109.000000
# 2019-04-25 00:14:00    109.202899
# 2019-04-25 00:29:00    109.710145
# 2019-04-25 00:44:00    110.217391
# 2019-04-25 00:50:00    110.420290

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.layouts import *
from bokeh.io import output_notebook
from bokeh.plotting import ColumnDataSource
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1002">Loading BokehJS ...</span>
#     </div>

# %%
Plot = figure(title="awesome glucose values", x_axis_label='Time', y_axis_label='Glucose values (mg/dL)')
legenda1=("Normal glucose levels")
Plot.circle(df['time'], df['glucose'] , color = "red", size = 10, legend_label=legenda1, line_width=2)
legenda2=('Interpolated glucose levels')
Plot.line(df['time'], df['interpolated'] , legend_label=legenda2, line_width=2)
show(Plot)
# Out:
#   <div id="a875b07c-efa9-4602-9740-a679361a09a0" data-root-id="p2262" style="display: contents;"></div>

# %%
# Out:
# ['ID', 'time', 'recordtype', 'glucose', 'interpolated']
